# %%
import sys
import os


sys.path.append(os.path.abspath(".."))

# %%
from src.journal_api import get_papers_dataframe

# %%
df = get_papers_dataframe(
    venue="Transactions of the Association for Computational Linguistics",
    fields_of_study="Computer Science",
    publication_types="JournalArticle",
    date_range="2010-01-01:2025-12-31"
)

df.head()
# Out:
#                                     paperId  \
# 0  cd0a1d660771c9d2fa42c9446fbc1f441d40e9d1
# 1  2ae77bb984dce5af3181a28340d603ad9bb0b9b1
# 2  03c605c8b0bdd7ce7e2123ab6394dcc25f70f6a9
# 3  21b3007f967d39e1346bc91e0fc8b3f16121300c
# 4  22566980b49e2b2d3594f9446f7398da5d344a5c
#
#                                                title  \
# 0  A Novel Feature-based Bayesian Model for Query...
# 1  Extensions of Ordering Sets of States from Eff...
# 2          Finding Optimal 1-Endpoint-Crossing Trees
# 3            Grounding Action Descriptions in Videos
# 4  Branch and Bound Algorithm for Dependency Pars...
#
#                                                venue  year  \
# 0  Transactions of the Association for Computatio...  2012
# 1  Transactions of the Association for Computatio...  2013
# 2  Transactions of the Association for Computatio...  2013
# 3  Transactions of the Association for Computatio...  2013
# 4  Transactions of the Association for Computatio...  2013
#
#                                        openAccessPdf publicationDate  \
# 0  {'url': 'http://www.mitpressjournals.org/doi/p...      2012-12-10
# 1  {'url': 'https://easychair.org/publications/op...      2013-02-24
# 2  {'url': 'http://www.mitpressjournals.org/doi/p...      2013-03-01
# 3  {'url': 'http://www.mitpressjournals.org/doi/p...      2013-03-31
# 4  {'url': 'http://www.mitpressjournals.org/doi/p...      2013-03-31
#
#                                              authors  \
# 0  [{'authorId': '2386020789', 'name': 'Jiwei Li'...
# 1  [{'authorId': '102679761', 'name': 'Ji R I Jan...
# 2  [{'authorId': '2585932', 'name': 'Emily Pitler...
# 3  [{'authorId': '2485529', 'name': 'Michaela Reg...
# 4  [{'authorId': '2067733840', 'name': 'Xian Qian...
#
#                                             abstract  month  \
# 0  Supervised learning methods and LDA based topi...     12
# 1                                               None      2
# 2  Dependency parsing algorithms capable of produ...      3
# 3  Recent work has shown that the integration of ...      3
# 4  Graph based dependency parsing is inefficient ...      3
#
#    four_month_section
# 0                   3
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
from src.journal_api import get_papers_dataframe

# %%
from src.embeddings import EmbeddingModel

embedder = EmbeddingModel()

# %%
test = embedder.encode_text("Machine learning for language understanding")
print(test.shape)
# Out:
# (384,)

# %%
from src.scoring import compute_similarity, summary_statistics

# %%
journal_scope = """
This journal publishes research in computational linguistics,
natural language processing, machine learning for language understanding,
syntax, semantics, discourse, multilingual NLP, and language generation.
"""

# %%
scope_embedding = embedder.encode_text(journal_scope)

article_embeddings = embedder.encode_list(
    df["abstract"].fillna("").tolist()
)
# Out:
# Batches:   0%|          | 0/27 [00:00<?, ?it/s]

# %%
scores = compute_similarity(article_embeddings, scope_embedding)

df["alignment_score"] = scores
df.head()
# Out:
#                                     paperId  \
# 0  cd0a1d660771c9d2fa42c9446fbc1f441d40e9d1
# 1  2ae77bb984dce5af3181a28340d603ad9bb0b9b1
# 2  03c605c8b0bdd7ce7e2123ab6394dcc25f70f6a9
# 3  21b3007f967d39e1346bc91e0fc8b3f16121300c
# 4  22566980b49e2b2d3594f9446f7398da5d344a5c
#
#                                                title  \
# 0  A Novel Feature-based Bayesian Model for Query...
# 1  Extensions of Ordering Sets of States from Eff...
# 2          Finding Optimal 1-Endpoint-Crossing Trees
# 3            Grounding Action Descriptions in Videos
# 4  Branch and Bound Algorithm for Dependency Pars...
#
#                                                venue  year  \
# 0  Transactions of the Association for Computatio...  2012
# 1  Transactions of the Association for Computatio...  2013
# 2  Transactions of the Association for Computatio...  2013
# 3  Transactions of the Association for Computatio...  2013
# 4  Transactions of the Association for Computatio...  2013
#
#                                        openAccessPdf publicationDate  \
# 0  {'url': 'http://www.mitpressjournals.org/doi/p...      2012-12-10
# 1  {'url': 'https://easychair.org/publications/op...      2013-02-24
# 2  {'url': 'http://www.mitpressjournals.org/doi/p...      2013-03-01
# 3  {'url': 'http://www.mitpressjournals.org/doi/p...      2013-03-31
# 4  {'url': 'http://www.mitpressjournals.org/doi/p...      2013-03-31
#
#                                              authors  \
# 0  [{'authorId': '2386020789', 'name': 'Jiwei Li'...
# 1  [{'authorId': '102679761', 'name': 'Ji R I Jan...
# 2  [{'authorId': '2585932', 'name': 'Emily Pitler...
# 3  [{'authorId': '2485529', 'name': 'Michaela Reg...
# 4  [{'authorId': '2067733840', 'name': 'Xian Qian...
#
#                                             abstract  month  \
# 0  Supervised learning methods and LDA based topi...     12
# 1                                               None      2
# 2  Dependency parsing algorithms capable of produ...      3
# 3  Recent work has shown that the integration of ...      3
# 4  Graph based dependency parsing is inefficient ...      3
#
#    four_month_section  alignment_score
# 0                   3         0.325082
# 1                   1         0.110379
# 2                   1         0.459423
# 3                   1         0.254377
# 4                   1         0.323969

# %%
summary_statistics(scores)
# Out:
# {'mean': 0.32718661427497864,
#  'median': 0.3403298258781433,
#  'min': 0.005456775426864624,
#  'max': 0.5357887744903564,
#  'std': 0.09092221409082413}

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.hist(df["alignment_score"], bins=20)
plt.title("Distribution of Alignment Scores")
plt.xlabel("Similarity Score")
plt.ylabel("Number of Papers")
plt.show()

# %%
df.sort_values("alignment_score").head(10)
# Out:
#                                       paperId  \
# 47   65f07a7076615f192438b7e286941462781735d9
# 22   6b5c4fadf664f7b44347ab086d3399600badc8a4
# 416  2c4581c771af5c594ac6cb4c2bd75a731a5a525f
# 28   6c7ecab290021406c5456f7531dd28a8e6383eb9
# 706  f2be957d225bc9863567b20ae51b87f991724320
# 530  23723a892a3ed48769c0e99f063d368c19aa9386
# 449  d97240a1002bb2e87278f9f8ce064802c18d22b4
# 69   51c51e2c10d05cf9809b8c7aa087b1de8aeeaef7
# 68   4cee83454d52443a3eef9ebaea4b7dc84ee47fa9
# 67   44459131cad48e1417eb883b8b1e2d94dd869395
#
#                                                  title  \
# 47                       Walker's Cancellation Theorem
# 22   Idempotent generated algebras and Boolean powe...
# 416  Erratum: “BLiMP: The Benchmark of Linguistic M...
# 28               The Benefits of a Model of Annotation
# 706  Removing Backdoors in Pre-trained Models by Re...
# 530  Erratum: Measuring and Improving Consistency i...
# 449  Retrieve Fast, Rerank Smart: Cooperative and J...
# 69                            Cuts for circular proofs
# 68   Two-layer modal logics: from fuzzy logics to a...
# 67   Projectivity and unification in the varieties ...
#
#                                                  venue  year  \
# 47   Transactions of the Association for Computatio...  2014
# 22   Transactions of the Association for Computatio...  2013
# 416  Transactions of the Association for Computatio...  2020
# 28   Transactions of the Association for Computatio...  2013
# 706  Transactions of the Association for Computatio...  2023
# 530  Transactions of the Association for Computatio...  2021
# 449  Transactions of the Association for Computatio...  2021
# 69   Transactions of the Association for Computatio...  2014
# 68   Transactions of the Association for Computatio...  2014
# 67   Transactions of the Association for Computatio...  2014
#
#                                          openAccessPdf publicationDate  \
# 47   {'url': 'https://arxiv.org/pdf/1510.02137', 's...      2014-04-03
# 22   {'url': 'https://easychair.org/publications/op...      2013-06-13
# 416  {'url': 'https://direct.mit.edu/tacl/article-p...      2020-12-01
# 28   {'url': 'http://www.mitpressjournals.org/doi/p...      2013-08-01
# 706  {'url': 'https://direct.mit.edu/tacl/article-p...      2023-12-01
# 530  {'url': 'https://direct.mit.edu/tacl/article-p...      2021-12-01
# 449  {'url': 'https://direct.mit.edu/tacl/article-p...      2021-03-22
# 69   {'url': 'https://easychair.org/publications/op...      2014-07-28
# 68   {'url': 'https://easychair.org/publications/op...      2014-07-28
# 67   {'url': 'https://easychair.org/publications/op...      2014-07-28
#
#                                                authors  \
# 47   [{'authorId': '1702697', 'name': 'Robert S. Lu...
# 22   [{'authorId': '3173969', 'name': 'G. Bezhanish...
# 416  [{'authorId': '46236380', 'name': 'Alex Warsta...
# 28   [{'authorId': '1703046', 'name': 'R. Passonnea...
# 706  [{'authorId': '2051651646', 'name': 'Biru Zhu'...
# 530  [{'authorId': '51131518', 'name': 'Yanai Elaza...
# 449  [{'authorId': '2000828470', 'name': 'Gregor Ge...
# 69   [{'authorId': '34604343', 'name': 'J. Fortier'...
# 68   [{'authorId': '1809046', 'name': 'P. Cintula'}...
# 67   [{'authorId': '3007371', 'name': 'A. Nola'}, {...
#
#                                               abstract  month  \
# 47   Walker's cancellation theorem says that, if B ...      4
# 22   A Boolean power S of a commutative ring R has ...      6
# 416  Abstract We correct wrongly reported results o...     12
# 28               Correction for the URL in footnote 7.      8
# 706  Abstract Recent research has revealed that pre...     12
# 530  Abstract During production of this paper, an e...     12
# 449  Current state-of-the-art approaches to cross- ...      3
# 69                                                None      7
# 68                                                None      7
# 67                                                None      7
#
#      four_month_section  alignment_score
# 47                    1         0.005457
# 22                    2         0.041144
# 416                   3         0.045693
# 28                    2         0.076065
# 706                   3         0.085159
# 530                   3         0.091922
# 449                   1         0.101739
# 69                    2         0.110379
# 68                    2         0.110379
# 67                    2         0.110379

# %%
df.sort_values("alignment_score", ascending=False).head(10)
# Out:
#                                       paperId  \
# 752  f5a9519c5e18abb7b0c6930ead110782b1dccbe8
# 452  47eaee2118831c958ce696f91139710bbecde229
# 371  afee13719b496fe3419c13b33bab28e012e50d80
# 512  9cf8035a255e1d94631741e450c2efd5162b3b4f
# 152  635e830502319b14025594f225848fa12b80d802
# 178  09826173b667807ba5f2dceab3ab8404c1dbd60d
# 31   0ec546aa8f6f9340020ddaa3f77b7b5b2541b559
# 608  6a9c43af590927c76dfa91b0050300048cecbc68
# 800  f508cb908111bbba30d60db7c2906eafefe564c9
# 366  83a820fe19944a7621238b8cfcc0b8a0cbc0f4b6
#
#                                                  title  \
# 752  The Thai Discourse Treebank: Annotating and Cl...
# 452  An Error Analysis Framework for Shallow Surfac...
# 371  Unsupervised Discourse Constituency Parsing Us...
# 512                           Text-based NP Enrichment
# 152  One Vector is Not Enough: Entity-Augmented Dis...
# 178                         Many Languages, One Parser
# 31   Joint Morphological and Syntactic Analysis for...
# 608  The Emergence of Argument Structure in Artific...
# 800  Benchmarking Linguistic Diversity of Large Lan...
# 366  TyDi QA: A Benchmark for Information-Seeking Q...
#
#                                                  venue  year  \
# 752  Transactions of the Association for Computatio...  2024
# 452  Transactions of the Association for Computatio...  2021
# 371  Transactions of the Association for Computatio...  2020
# 512  Transactions of the Association for Computatio...  2021
# 152  Transactions of the Association for Computatio...  2015
# 178  Transactions of the Association for Computatio...  2016
# 31   Transactions of the Association for Computatio...  2013
# 608  Transactions of the Association for Computatio...  2022
# 800  Transactions of the Association for Computatio...  2024
# 366  Transactions of the Association for Computatio...  2020
#
#                                          openAccessPdf publicationDate  \
# 752  {'url': 'https://direct.mit.edu/tacl/article-p...      2024-05-01
# 452  {'url': 'https://direct.mit.edu/tacl/article-p...      2021-04-01
# 371  {'url': 'https://doi.org/10.1162/tacl_a_00312'...      2020-04-01
# 512  {'url': 'https://direct.mit.edu/tacl/article-p...      2021-09-24
# 152  {'url': 'http://www.mitpressjournals.org/doi/p...      2015-06-10
# 178  {'url': 'http://www.mitpressjournals.org/doi/p...      2016-02-04
# 31   {'url': 'https://doi.org/10.1162/tacl_a_00238'...      2013-10-31
# 608  {'url': 'https://direct.mit.edu/tacl/article-p...      2022-12-01
# 800  {'url': '', 'status': None, 'license': None, '...      2024-12-13
# 366  {'url': 'https://direct.mit.edu/tacl/article-p...      2020-03-10
#
#                                                authors  \
# 752  [{'authorId': '1419954915', 'name': 'Ponrawee ...
# 452  [{'authorId': '2181869', 'name': 'Anastasia Sh...
# 371  [{'authorId': '8058716', 'name': 'Noriki Nishi...
# 512  [{'authorId': '51131518', 'name': 'Yanai Elaza...
# 152  [{'authorId': '40608686', 'name': 'Yangfeng Ji...
# 178  [{'authorId': '145585097', 'name': 'Bridger Wa...
# 31   [{'authorId': '1678747', 'name': 'Bernd Bohnet...
# 608  [{'authorId': '3448428', 'name': 'Tom Bosc'}, ...
# 800  [{'authorId': '2155600393', 'name': 'Yanzhu Gu...
# 366  [{'authorId': '144797264', 'name': 'J. Clark'}...
#
#                                               abstract  month  \
# 752  Discourse analysis is a highly applicable area...      5
# 452  Abstract The metrics standardly used to evalua...      4
# 371  In this paper, we introduce an unsupervised di...      4
# 512  Abstract Understanding the relations between e...      9
# 152  Discourse relations bind smaller linguistic un...      6
# 178  We train one multilingual model for dependency...      2
# 31   Joint morphological and syntactic analysis has...     10
# 608  Abstract Computational approaches to the study...     12
# 800  \n The development and evaluation of Large Lan...     12
# 366  Abstract Confidently making progress on multil...      3
#
#      four_month_section  alignment_score
# 752                   2         0.535789
# 452                   1         0.510715
# 371                   1         0.505973
# 512                   3         0.504872
# 152                   2         0.503060
# 178                   1         0.502632
# 31                    3         0.497887
# 608                   3         0.495733
# 800                   3         0.492473
# 366                   1         0.491257

# %%
yearly_scores = df.groupby("year")["alignment_score"].agg(
    mean="mean",
    median="median",
    count="count",
    std="std"
).reset_index()

yearly_scores
# Out:
#     year      mean    median  count       std
# 0   2012  0.325082  0.325082      1       NaN
# 1   2013  0.329460  0.343904     40  0.120585
# 2   2014  0.228267  0.110379     89  0.129410
# 3   2015  0.346987  0.354844     51  0.067389
# 4   2016  0.347634  0.340763     45  0.069352
# 5   2017  0.343486  0.346727     43  0.072964
# 6   2018  0.369643  0.372845     34  0.063732
# 7   2019  0.352754  0.365083     55  0.071133
# 8   2020  0.337710  0.339367     74  0.077190
# 9   2021  0.342617  0.348362    107  0.078221
# 10  2022  0.348519  0.347781     81  0.077953
# 11  2023  0.322956  0.332101     98  0.071435
# 12  2024  0.329762  0.331195     93  0.074317
# 13  2025  0.312515  0.310912     51  0.082518

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(yearly_scores["year"], yearly_scores["mean"], marker="o")
plt.title("Average Thematic Alignment by Year")
plt.xlabel("Year")
plt.ylabel("Mean Alignment Score")
plt.grid(True, alpha=0.3)
plt.show()

# %%
low = df.sort_values("alignment_score").head(10)
low[["year","title","alignment_score"]]
# Out:
#      year                                              title  alignment_score
# 47   2014                      Walker's Cancellation Theorem         0.005457
# 22   2013  Idempotent generated algebras and Boolean powe...         0.041144
# 416  2020  Erratum: “BLiMP: The Benchmark of Linguistic M...         0.045693
# 28   2013              The Benefits of a Model of Annotation         0.076065
# 706  2023  Removing Backdoors in Pre-trained Models by Re...         0.085159
# 530  2021  Erratum: Measuring and Improving Consistency i...         0.091922
# 449  2021  Retrieve Fast, Rerank Smart: Cooperative and J...         0.101739
# 69   2014                           Cuts for circular proofs         0.110379
# 68   2014  Two-layer modal logics: from fuzzy logics to a...         0.110379
# 67   2014  Projectivity and unification in the varieties ...         0.110379

# %%
high = df.sort_values("alignment_score", ascending=False).head(10)
high[["year","title","alignment_score"]]
# Out:
#      year                                              title  alignment_score
# 752  2024  The Thai Discourse Treebank: Annotating and Cl...         0.535789
# 452  2021  An Error Analysis Framework for Shallow Surfac...         0.510715
# 371  2020  Unsupervised Discourse Constituency Parsing Us...         0.505973
# 512  2021                           Text-based NP Enrichment         0.504872
# 152  2015  One Vector is Not Enough: Entity-Augmented Dis...         0.503060
# 178  2016                         Many Languages, One Parser         0.502632
# 31   2013  Joint Morphological and Syntactic Analysis for...         0.497887
# 608  2022  The Emergence of Argument Structure in Artific...         0.495733
# 800  2024  Benchmarking Linguistic Diversity of Large Lan...         0.492473
# 366  2020  TyDi QA: A Benchmark for Information-Seeking Q...         0.491257

# %%
papers_per_year = df["year"].value_counts().sort_index()

plt.figure(figsize=(12,5))
papers_per_year.plot(kind="bar")
plt.title("Number of Papers Published per Year")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(yearly_scores["year"], yearly_scores["mean"], marker="o", linewidth=2)
plt.fill_between(
    yearly_scores["year"],
    yearly_scores["mean"] - yearly_scores["std"].fillna(0),
    yearly_scores["mean"] + yearly_scores["std"].fillna(0),
    alpha=0.2
)
plt.title("Average Alignment by Year (± Std Dev)")
plt.xlabel("Year")
plt.ylabel("Mean Alignment")
plt.grid(alpha=0.3)
plt.show()

# %%
df["year"].value_counts().sort_index()
# Out:
# year
# 2012      1
# 2013     40
# 2014     89
# 2015     51
# 2016     45
# 2017     43
# 2018     34
# 2019     55
# 2020     74
# 2021    107
# 2022     81
# 2023     98
# 2024     93
# 2025     51
# Name: count, dtype: int64

# %%
df.sort_values("alignment_score", ascending=False)[["year","title","alignment_score"]].head(10)
# Out:
#      year                                              title  alignment_score
# 752  2024  The Thai Discourse Treebank: Annotating and Cl...         0.535789
# 452  2021  An Error Analysis Framework for Shallow Surfac...         0.510715
# 371  2020  Unsupervised Discourse Constituency Parsing Us...         0.505973
# 512  2021                           Text-based NP Enrichment         0.504872
# 152  2015  One Vector is Not Enough: Entity-Augmented Dis...         0.503060
# 178  2016                         Many Languages, One Parser         0.502632
# 31   2013  Joint Morphological and Syntactic Analysis for...         0.497887
# 608  2022  The Emergence of Argument Structure in Artific...         0.495733
# 800  2024  Benchmarking Linguistic Diversity of Large Lan...         0.492473
# 366  2020  TyDi QA: A Benchmark for Information-Seeking Q...         0.491257

# %%
df.sort_values("alignment_score")[["year","title","alignment_score"]].head(10)
# Out:
#      year                                              title  alignment_score
# 47   2014                      Walker's Cancellation Theorem         0.005457
# 22   2013  Idempotent generated algebras and Boolean powe...         0.041144
# 416  2020  Erratum: “BLiMP: The Benchmark of Linguistic M...         0.045693
# 28   2013              The Benefits of a Model of Annotation         0.076065
# 706  2023  Removing Backdoors in Pre-trained Models by Re...         0.085159
# 530  2021  Erratum: Measuring and Improving Consistency i...         0.091922
# 449  2021  Retrieve Fast, Rerank Smart: Cooperative and J...         0.101739
# 69   2014                           Cuts for circular proofs         0.110379
# 68   2014  Two-layer modal logics: from fuzzy logics to a...         0.110379
# 67   2014  Projectivity and unification in the varieties ...         0.110379

# %%
yearly_scores["count"].corr(yearly_scores["mean"])
# Out:
# np.float64(-0.27483709921020244)

# %%
## Representation

# %%
papers_per_year = df["year"].value_counts().sort_index()
papers_per_year
# Out:
# year
# 2012      1
# 2013     40
# 2014     89
# 2015     51
# 2016     45
# 2017     43
# 2018     34
# 2019     55
# 2020     74
# 2021    107
# 2022     81
# 2023     98
# 2024     93
# 2025     51
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
papers_per_year.plot(kind="bar")
plt.title("Number of Papers Published Per Year")
plt.xlabel("Year")
plt.ylabel("Count")
plt.grid(axis="y", alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.hist(df["alignment_score"], bins=25, edgecolor="black")
plt.axvline(df["alignment_score"].mean(), linestyle="--", linewidth=2, label="Mean")
plt.axvline(df["alignment_score"].median(), linestyle=":", linewidth=2, label="Median")
plt.title("Distribution of Alignment Scores")
plt.xlabel("Similarity Score")
plt.ylabel("Number of Papers")
plt.legend()
plt.show()

# %%
low_papers = df.sort_values("alignment_score").head(10)
low_papers[["year", "title", "alignment_score"]]
# Out:
#      year                                              title  alignment_score
# 47   2014                      Walker's Cancellation Theorem         0.005457
# 22   2013  Idempotent generated algebras and Boolean powe...         0.041144
# 416  2020  Erratum: “BLiMP: The Benchmark of Linguistic M...         0.045693
# 28   2013              The Benefits of a Model of Annotation         0.076065
# 706  2023  Removing Backdoors in Pre-trained Models by Re...         0.085159
# 530  2021  Erratum: Measuring and Improving Consistency i...         0.091922
# 449  2021  Retrieve Fast, Rerank Smart: Cooperative and J...         0.101739
# 69   2014                           Cuts for circular proofs         0.110379
# 68   2014  Two-layer modal logics: from fuzzy logics to a...         0.110379
# 67   2014  Projectivity and unification in the varieties ...         0.110379

# %%
high_papers = df.sort_values("alignment_score", ascending=False).head(10)
high_papers[["year", "title", "alignment_score"]]
# Out:
#      year                                              title  alignment_score
# 752  2024  The Thai Discourse Treebank: Annotating and Cl...         0.535789
# 452  2021  An Error Analysis Framework for Shallow Surfac...         0.510715
# 371  2020  Unsupervised Discourse Constituency Parsing Us...         0.505973
# 512  2021                           Text-based NP Enrichment         0.504872
# 152  2015  One Vector is Not Enough: Entity-Augmented Dis...         0.503060
# 178  2016                         Many Languages, One Parser         0.502632
# 31   2013  Joint Morphological and Syntactic Analysis for...         0.497887
# 608  2022  The Emergence of Argument Structure in Artific...         0.495733
# 800  2024  Benchmarking Linguistic Diversity of Large Lan...         0.492473
# 366  2020  TyDi QA: A Benchmark for Information-Seeking Q...         0.491257

# %%
plt.figure(figsize=(14,6))
df.boxplot(column="alignment_score", by="year", grid=False, rot=45)
plt.title("Alignment Score Distribution by Year")
plt.suptitle("")
plt.xlabel("Year")
plt.ylabel("Alignment Score")
plt.show()

# %%
merged = yearly_scores.merge(
    papers_per_year.rename("count"),
    left_on="year",
    right_index=True
)

# %%
print(merged.columns)
# Out:
# Index(['year', 'mean', 'median', 'count_x', 'std', 'count_y'], dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

sns.heatmap(
    merged[["mean", "median", "count_x", "std"]].corr(),
    annot=True,
    cmap="Blues"
)

plt.title("Correlation Between Yearly Metrics")
plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)

pca_result = pca.fit_transform(article_embeddings)

df["pca1"] = pca_result[:, 0]
df["pca2"] = pca_result[:, 1]

# %%
plt.figure(figsize=(12,8))

plt.scatter(
    df["pca1"],
    df["pca2"],
    alpha=0.7
)

plt.title("Semantic Map of Journal Articles (PCA Projection)")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.grid(alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(12,8))

scatter = plt.scatter(
    df["pca1"],
    df["pca2"],
    c=df["alignment_score"],
    alpha=0.8
)

plt.colorbar(scatter, label="Alignment Score")

plt.title("Semantic Distribution Colored by Alignment")
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.grid(alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(12,8))

scatter = plt.scatter(
    df["pca1"],
    df["pca2"],
    c=df["cluster"],
    alpha=0.8
)

plt.title("Semantic Clusters of Journal Papers")
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.grid(alpha=0.3)
plt.show()

# %%
# Methodology

## Data Source
## The dataset was collected using the Semantic Scholar API.  
## The selected journal was *Transactions of the Association for Computational Linguistics (TACL)*.

## Textual Inputs
## For each publication, the article abstract was used as the textual representation.  
## The journal's aims and scope statement was used as the thematic reference document.

## NLP Representation
## Texts were converted into dense semantic embeddings using the Sentence-BERT model:

## `all-MiniLM-L6-v2`

## Similarity Measure
## Cosine similarity was computed between each article embedding and the journal scope embedding.

## Objective
## The objective is to evaluate how strongly published articles align with the stated thematic focus of the journal.

# %%
## PHASE 2

# %%
# !pip install keybert
# Out:
# Collecting keybert
#   Downloading keybert-0.9.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.18.5 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from keybert) (2.4.1)
# Collecting rich>=10.4.0 (from keybert)
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: scikit-learn>=0.22.2 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from keybert) (1.8.0)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from keybert) (5.4.1)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.4.0->keybert)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from rich>=10.4.0->keybert) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: scipy>=1.10.0 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from scikit-learn>=0.22.2->keybert) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from scikit-learn>=0.22.2->keybert) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from scikit-learn>=0.22.2->keybert) (3.5.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from sentence-transformers>=0.3.8->keybert) (4.49.0)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from sentence-transformers>=0.3.8->keybert) (0.34.4)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from sentence-transformers>=0.3.8->keybert) (2.8.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from sentence-transformers>=0.3.8->keybert) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from sentence-transformers>=0.3.8->keybert) (4.67.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (3.20.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (2025.11.3)
# Requirement already satisfied: requests in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->sentence-transformers>=0.3.8->keybert) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->sentence-transformers>=0.3.8->keybert) (1.1.8)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.1.6)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/nlp_transformers/lib/python3.13/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (2026.1.4)
# Downloading keybert-0.9.0-py3-none-any.whl (41 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: mdurl, markdown-it-py, rich, keybert
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [keybert]
# Successfully installed keybert-0.9.0 markdown-it-py-4.0.0 mdurl-0.1.2 rich-15.0.0

# %%
from keybert import KeyBERT

kw_model = KeyBERT()

keywords = kw_model.extract_keywords(
    journal_scope,
    keyphrase_ngram_range=(1,2),
    stop_words="english",
    top_n=8
)

keywords
# Out:
# [('computational linguistics', 0.6935),
#  ('nlp language', 0.5999),
#  ('multilingual nlp', 0.5603),
#  ('language generation', 0.542),
#  ('linguistics', 0.5384),
#  ('language processing', 0.5351),
#  ('natural language', 0.5305),
#  ('linguistics natural', 0.5259)]

# %%
labels = [k[0] for k in keywords]
labels
# Out:
# ['computational linguistics',
#  'nlp language',
#  'multilingual nlp',
#  'language generation',
#  'linguistics',
#  'language processing',
#  'natural language',
#  'linguistics natural']

# %%
from transformers import pipeline

classifier = pipeline(
    "zero-shot-classification",
    model="facebook/bart-large-mnli"
)
# Out:
# Device set to use mps:0

# %%
sample_text = df["abstract"].dropna().iloc[0]

classifier(sample_text, labels)
# Out:
# {'sequence': 'Supervised learning methods and LDA based topic model have been successfully applied in the field of multi-document summarization. In this paper, we propose a novel supervised approach that can incorporate rich sentence features into Bayesian topic models in a principled way, thus taking advantages of both topic model and feature based supervised learning methods. Experimental results on DUC2007, TAC2008 and TAC2009 demonstrate the effectiveness of our approach.',
#  'labels': ['linguistics natural',
#   'nlp language',
#   'language processing',
#   'multilingual nlp',
#   'natural language',
#   'computational linguistics',
#   'language generation',
#   'linguistics'],
#  'scores': [0.18085835874080658,
#   0.17568475008010864,
#   0.15342773497104645,
#   0.1298477202653885,
#   0.11653927713632584,
#   0.10505614429712296,
#   0.07239113003015518,
#   0.06619488447904587]}

# %%
labels
# Out:
# ['computational linguistics',
#  'nlp language',
#  'multilingual nlp',
#  'language generation',
#  'linguistics',
#  'language processing',
#  'natural language',
#  'linguistics natural']

# %%
clean_labels = [
    "Computational Linguistics",
    "Natural Language Processing",
    "Language Processing",
    "Multilingual NLP",
    "Language Generation",
    "Linguistics"
]

# %%
sample_df = df[df["abstract"].notna()].head(30).copy()

sample_df["predicted_topic"] = sample_df["abstract"].apply(
    lambda x: classifier(x, clean_labels)["labels"][0]
)

sample_df[["year", "title", "predicted_topic"]]
# Out:
#     year                                              title  \
# 0   2012  A Novel Feature-based Bayesian Model for Query...
# 2   2013          Finding Optimal 1-Endpoint-Crossing Trees
# 3   2013            Grounding Action Descriptions in Videos
# 4   2013  Branch and Bound Algorithm for Dependency Pars...
# 5   2013  Unsupervised Dependency Parsing with Acoustic ...
# 6   2013  Token and Type Constraints for Cross-Lingual P...
# 7   2013  Weakly Supervised Learning of Semantic Parsers...
# 8   2013  An HDP Model for Inducing Combinatory Categori...
# 9   2013  Dijkstra-WSA: A Graph-Based Approach to Word S...
# 10  2013  Minimally-Supervised Morphological Segmentatio...
# 11  2013  Incremental Tree Substitution Grammar for Pars...
# 12  2013      Combined Distributional and Logical Semantics
# 13  2013  Using Pivot-Based Paraphrasing and Sentiment P...
# 14  2013  Dual Coordinate Descent Algorithms for Efficie...
# 15  2013  Modeling Semantic Relations Expressed by Prepo...
# 16  2013  Joint Arc-factored Parsing of Syntactic and Se...
# 17  2013      Modeling Child Divergences from Adult Grammar
# 18  2013  Unsupervised Tree Induction for Tree-based Tra...
# 19  2013  Jointly Learning to Parse and Perceive: Connec...
# 20  2013  Learning to translate with products of novices...
# 21  2013  Efficient Stacked Dependency Parsing by Forest...
# 22  2013  Idempotent generated algebras and Boolean powe...
# 23  2013  What Makes Writing Great? First Experiments on...
# 24  2013  Parsing entire discourses as very long strings...
# 25  2013  Good, Great, Excellent: Global Inference of Se...
# 26  2013  Large-scale Word Alignment Using Soft Dependen...
# 27  2013  Dynamically Shaping the Reordering Search Spac...
# 28  2013              The Benefits of a Model of Annotation
# 29  2013  Distributional Semantics Beyond Words: Supervi...
# 30  2013  Measuring Machine Translation Errors in New Do...
#
#                 predicted_topic
# 0           Language Processing
# 2   Natural Language Processing
# 3   Natural Language Processing
# 4           Language Processing
# 5           Language Processing
# 6           Language Processing
# 7   Natural Language Processing
# 8                   Linguistics
# 9     Computational Linguistics
# 10    Computational Linguistics
# 11          Language Processing
# 12  Natural Language Processing
# 13  Natural Language Processing
# 14  Natural Language Processing
# 15  Natural Language Processing
# 16          Language Processing
# 17                  Linguistics
# 18          Language Processing
# 19  Natural Language Processing
# 20  Natural Language Processing
# 21          Language Processing
# 22             Multilingual NLP
# 23          Language Generation
# 24                  Linguistics
# 25  Natural Language Processing
# 26                  Linguistics
# 27          Language Processing
# 28             Multilingual NLP
# 29                  Linguistics
# 30             Multilingual NLP

# %%
sample_df["predicted_topic"].value_counts()
# Out:
# predicted_topic
# Natural Language Processing    10
# Language Processing             9
# Linguistics                     5
# Multilingual NLP                3
# Computational Linguistics       2
# Language Generation             1
# Name: count, dtype: int64
